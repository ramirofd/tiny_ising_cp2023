# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load data into a pandas dataframe
df = pd.read_csv('../results/size_comparison_32_1024_local.csv')

# Use seaborn to create a line plot
sns.scatterplot(x='L', y='time', data=df)

# Set the plot title and axis labels
plt.title('Time vs Grid Size')
plt.xlabel('Grid Size')
plt.ylabel('Time')
plt.xticks(df.L.unique(), rotation=90)

# Show the plot
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load data into a pandas dataframe
df = pd.read_csv('../results/size_comparison_metric_local.csv')

# Use seaborn to create a line plot
sns.scatterplot(x='L', y='time', data=df)

# Set the plot title and axis labels
plt.title('Metric vs Grid Size')
plt.xlabel('Grid Size')
plt.ylabel('Metric [p/s]')
plt.xticks(df.L.unique(), rotation=90)

# Show the plot
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load data into a pandas dataframe
df = pd.read_csv('../results/optimization_flags_local.csv')

# Use seaborn to create a line plot
print(df.columns)
ax = sns.barplot(x='flags', y='metric', hue='compiler', data=df)
# Add labels with the value of each bar
for rect in ax.patches:
    # Get the height and width of the bar
    height = rect.get_height()
    width = rect.get_width()

    # Get the x and y coordinates of the bar
    x = rect.get_x()
    y = rect.get_y()

    # Add a label with the value of the bar
    ax.text(x + width/2, y + height/2, '{:.2f}'.format(height), ha='center', va='center', color='white', rotation=90)

# Set the plot title and axis labels
plt.title('Metric vs Flags for GCC/CLang')
plt.xlabel('Flags')
plt.ylabel('Metric [p/s]')
# plt.xticks(df.L.unique(), rotation=90)

# Show the plot
plt.show()
# Out:
# Index(['compiler', 'flags', 'L', 'metric'], dtype='object')

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load data into a pandas dataframe
df = pd.read_csv('../results/optimization_flags_remote_zx81.csv')

# Use seaborn to create a line plot
print(df.columns)
ax = sns.barplot(x='flags', y='metric', hue='compiler', data=df)
# Add labels with the value of each bar
for rect in ax.patches:
    # Get the height and width of the bar
    height = rect.get_height()
    width = rect.get_width()

    # Get the x and y coordinates of the bar
    x = rect.get_x()
    y = rect.get_y()

    # Add a label with the value of the bar
    ax.text(x + width/2, y + height/2, '{:.2f}'.format(height), ha='center', va='center', color='white', rotation=90)

# Set the plot title and axis labels
plt.title('Metric vs Flags for GCC/CLang')
plt.xlabel('Flags')
plt.ylabel('Metric [p/s]')
# plt.xticks(df.L.unique(), rotation=90)

# Show the plot
plt.show()
# Out:
# Index(['compiler', 'flags', 'L', 'metric'], dtype='object')

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load data into a pandas dataframe
df = pd.read_csv('../results/optimization_flags_remote_atom.csv')

# Use seaborn to create a line plot
print(df.columns)
ax = sns.barplot(x='flags', y='metric', hue='compiler', data=df)
# Add labels with the value of each bar
for rect in ax.patches:
    # Get the height and width of the bar
    height = rect.get_height()
    width = rect.get_width()

    # Get the x and y coordinates of the bar
    x = rect.get_x()
    y = rect.get_y()

    # Add a label with the value of the bar
    ax.text(x + width/2, y + height/2, '{:.2f}'.format(height), ha='center', va='center', color='white', rotation=90)

# Set the plot title and axis labels
plt.title('Metric vs Flags for GCC/CLang')
plt.xlabel('Flags')
plt.ylabel('Metric [p/s]')
# plt.xticks(df.L.unique(), rotation=90)

# Show the plot
plt.show()
# Out:
# Index(['compiler', 'flags', 'L', 'metric'], dtype='object')

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load data into a pandas dataframe
df = pd.read_csv('../results/modified_code.csv')
df['hue'] = df['code']+' '+df['flags']
# Use seaborn to create a line plot
print(df.columns)
ax = sns.barplot(x='host', y='metric', hue='hue', data=df)
# Add labels with the value of each bar
for rect in ax.patches:
    # Get the height and width of the bar
    height = rect.get_height()
    width = rect.get_width()

    # Get the x and y coordinates of the bar
    x = rect.get_x()
    y = rect.get_y()

    # Add a label with the value of the bar
    ax.text(x + width/2, y + height/2, '{:.2f}'.format(height), ha='center', va='center', color='white', rotation=90)

# Set the plot title and axis labels
plt.title('Metric vs Flags for GCC/CLang')
plt.xlabel('Flags')
plt.ylabel('Metric [p/s]')
# plt.xticks(df.L.unique(), rotation=90)

# Show the plot
plt.show()
# Out:
# Index(['host', 'code', 'compiler', 'flags', 'L', 'metric', 'hue'], dtype='object')

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load data into a pandas dataframe
df = pd.read_csv('../results/sim_rb.csv')
df['version'] = 'modified_flags'
df1 = pd.read_csv('../results/sim_original_noflags.csv')
df1['version'] = 'original_noflags'

df = pd.concat([df, df1])
# Use seaborn to create a line plot
sns.lineplot(x='Temp', y='E', hue='version', data=df)

# Set the plot title and axis labels
plt.title('Energy vs Temperature')
plt.xlabel('Temperature')
plt.ylabel('Energy')

# Show the plot
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load data into a pandas dataframe
df = pd.read_csv('../results/sim_rb.csv')
df['version'] = 'modified_flags'
df1 = pd.read_csv('../results/sim_original_noflags.csv')
df1['version'] = 'original_noflags'

df = pd.concat([df, df1])
# Use seaborn to create a line plot
sns.lineplot(x='Temp', y='M', hue='version', data=df)

# Set the plot title and axis labels
plt.title('Magnetization vs Temperature')
plt.xlabel('Temperature')
plt.ylabel('Magnetization')

# Show the plot
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load data into a pandas dataframe
df = pd.read_csv('../results/metrics.csv')

# Create a 'hue' column by combining 'mejoras' and 'grid' columns

# Use seaborn to create a bar plot
ax = sns.barplot(x='mejoras', y='metric', data=df)

# Add labels with the value of each bar
for rect in ax.patches:
    # Get the height and width of the bar
    height = rect.get_height()
    width = rect.get_width()

    # Get the x and y coordinates of the bar
    x = rect.get_x()
    y = rect.get_y()

    # Add a label with the value of the bar
    ax.text(x + width/2, y + height/2, '{:.2f}'.format(height), ha='center', va='center', color='white', rotation=90)

# Set the plot title and axis labels
plt.title('Metric vs Flags for GCC/CLang')
plt.xlabel('Mejoras')
plt.ylabel('Metric [p/s]')
# Rotate x-axis labels by 45 degrees
plt.xticks(rotation=90)

# Show the plot
plt.show()
